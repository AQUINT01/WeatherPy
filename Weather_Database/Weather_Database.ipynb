# %%
# Dependencies and Setup

import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import gmaps
import json


# Import API key from a file
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities

lat_lngs = []
cities = []
countries = []

# Create a set of random lat and lng combinations

lats = np.random.uniform(low = -90, high = 90, size = 2000)
lngs = np.random.uniform(low = -180, high = 180, size = 2000)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Print the city count to confirm sufficient count

print(len(cities))
print(len(countries))
# Out:
# 768
# 768

# %%
# 1. create dataframe

weatherPy_city_df = pd.DataFrame({"City": cities, "Country": countries})
weatherPy_city_df.head()
# Out:
#            City Country
# 0      acapulco      mx
# 1        albany      au
# 2     geraldton      au
# 3  marsa matruh      eg
# 4       ushuaia      ar

# %%
# 2. create sample size of 2000 (Option 2)

import dask.dataframe as dd
weatherPy_city_df = dd.from_pandas(weatherPy_city_df, npartitions=1)
weatherPy_city_df.sample(frac=2, replace=True).compute()
# Out:
#                 City Country
# 440  verkhnevilyuysk      ru
# 620      san vicente      ph
# 20      saint george      bm
# 214       kamenskoye      ru
# 661            erzin      ru
# ..               ...     ...
# 548          klobuck      pl
# 266           elmira      us
# 115        shubarshi      kz
# 61             vidim      ru
# 438            sitka      us
#
# [1536 rows x 2 columns]

# %%
# Starting URL for Weather Map API Call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f470e631f5aee5148eae360489093a56

# %%
# Set up lists to hold reponse info

city = []
country = []
lat = []
lon = []
temp = []
humid = []
cloud = []
wind = []
description = []
count = 0

# Identify nearest city for each lat, lng combination

for index,row in weatherPy_city_df.iterrows():
    query_url = url + "&q=" + row["City"]
    count +=1
    print(f"Processing record {count} for the city: {row['City']}")
    response = requests.get(query_url).json()
    if response["cod"] == "404":
        print("Data not found... skip.")
        
    else:
        print(f"Record found for the city: {row['City']}")
        city.append(response["name"])
        country.append(response["sys"]["country"])
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        temp.append(response["main"]["temp_max"])
        humid.append(response["main"]["humidity"])
        cloud.append(response["clouds"]["all"])
        wind.append(response["wind"]["speed"])
        description.append(response["weather"][0]["description"])
# Out:
# Processing record 1 for the city: acapulco
# Record found for the city: acapulco
# Processing record 2 for the city: albany
# Record found for the city: albany
# Processing record 3 for the city: geraldton
# Record found for the city: geraldton
# Processing record 4 for the city: marsa matruh
# Record found for the city: marsa matruh
# Processing record 5 for the city: ushuaia
# Record found for the city: ushuaia
# Processing record 6 for the city: illoqqortoormiut
# Data not found... skip.
# Processing record 7 for the city: taolanaro
# Data not found... skip.
# Processing record 8 for the city: arraial do cabo
# Record found for the city: arraial do cabo
# Processing record 9 for the city: airai
# Record found for the city: airai
# Processing record 10 for the city: narsaq
# Record found for the city: narsaq
# Processing record 11 for the city: hobart
# Record found for the city: hobart
# Processing record 12 for the city: santa catalina
# Record found for the city: santa catalina
# Processing record 13 for the city: fukue
# Record found for the city: fukue
# Processing record 14 for the city: kodiak
# Record found for the city: kodiak
# Processing record 15 for the city: punta arenas
# Record found for the city: punta arenas
# Processing record 16 for the city: hereford
# Record found for the city: hereford
# Processing record 17 for the city: ninghai
# Record found for the city: ninghai
# Processing record 18 for the city: carutapera
# Record found for the city: carutapera
# Processing record 19 for the city: broome
# Record found for the city: broome
# Processing record 20 for the city: cabedelo
# Record found for the city: cabedelo
# Processing record 21 for the city: saint george
# Record found for the city: saint george
# Processing record 22 for the city: roebourne
# Record found for the city: roebourne
# Processing record 23 for the city: rocha
# Record found for the city: rocha
# Processing record 24 for the city: devils lake
# Record found for the city: devils lake
# Processing record 25 for the city: iqaluit
# Record found for the city: iqaluit
# Processing record 26 for the city: upernavik
# Record found for the city: upernavik
# Processing record 27 for the city: olinda
# Record found for the city: olinda
# Processing record 28 for the city: san quintin
# Record found for the city: san quintin
# Processing record 29 for the city: bluff
# Record found for the city: bluff
# Processing record 30 for the city: cherskiy
# Record found for the city: cherskiy
# Processing record 31 for the city: clyde river
# Record found for the city: clyde river
# Processing record 32 for the city: mercedes
# Record found for the city: mercedes
# Processing record 33 for the city: katsuura
# Record found for the city: katsuura
# Processing record 34 for the city: bethel
# Record found for the city: bethel
# Processing record 35 for the city: qaanaaq
# Record found for the city: qaanaaq
# Processing record 36 for the city: mataura
# Record found for the city: mataura
# Processing record 37 for the city: atuona
# Record found for the city: atuona
# Processing record 38 for the city: rikitea
# Record found for the city: rikitea
# Processing record 39 for the city: yanam
# Record found for the city: yanam
# Processing record 40 for the city: herat
# Record found for the city: herat
# Processing record 41 for the city: lagoa
# Record found for the city: lagoa
# Processing record 42 for the city: talnakh
# Record found for the city: talnakh
# Processing record 43 for the city: barentsburg
# Data not found... skip.
# Processing record 44 for the city: victoria
# Record found for the city: victoria
# Processing record 45 for the city: magdagachi
# Record found for the city: magdagachi
# Processing record 46 for the city: talant
# Record found for the city: talant
# Processing record 47 for the city: busselton
# Record found for the city: busselton
# Processing record 48 for the city: sibolga
# Record found for the city: sibolga
# Processing record 49 for the city: nkhata bay
# Record found for the city: nkhata bay
# Processing record 50 for the city: andenes
# Record found for the city: andenes
# Processing record 51 for the city: severo-kurilsk
# Record found for the city: severo-kurilsk
# Processing record 52 for the city: svobodnyy
# Record found for the city: svobodnyy
# Processing record 53 for the city: duz
# Data not found... skip.
# Processing record 54 for the city: new norfolk
# Record found for the city: new norfolk
# Processing record 55 for the city: bubaque
# Record found for the city: bubaque
# Processing record 56 for the city: torbay
# Record found for the city: torbay
# Processing record 57 for the city: marcona
# Data not found... skip.
# Processing record 58 for the city: hermanus
# Record found for the city: hermanus
# Processing record 59 for the city: minot
# Record found for the city: minot
# Processing record 60 for the city: dolinsk
# Record found for the city: dolinsk
# Processing record 61 for the city: tombouctou
# Record found for the city: tombouctou
# Processing record 62 for the city: vidim
# Record found for the city: vidim
# Processing record 63 for the city: barrow
# Record found for the city: barrow
# Processing record 64 for the city: port blair
# Record found for the city: port blair
# Processing record 65 for the city: calabozo
# Record found for the city: calabozo
# Processing record 66 for the city: attawapiskat
# Data not found... skip.
# Processing record 67 for the city: belushya guba
# Data not found... skip.
# Processing record 68 for the city: kapaa
# Record found for the city: kapaa
# Processing record 69 for the city: puerto ayora
# Record found for the city: puerto ayora
# Processing record 70 for the city: sopotnica
# Record found for the city: sopotnica
# Processing record 71 for the city: jamestown
# Record found for the city: jamestown
# Processing record 72 for the city: souillac
# Record found for the city: souillac
# Processing record 73 for the city: dikson
# Record found for the city: dikson
# Processing record 74 for the city: north platte
# Record found for the city: north platte
# Processing record 75 for the city: vaini
# Record found for the city: vaini
# Processing record 76 for the city: lebu
# Record found for the city: lebu
# Processing record 77 for the city: kieta
# Record found for the city: kieta
# Processing record 78 for the city: ondjiva
# Record found for the city: ondjiva
# Processing record 79 for the city: bambous virieux
# Record found for the city: bambous virieux
# Processing record 80 for the city: saint-augustin
# Record found for the city: saint-augustin
# Processing record 81 for the city: pevek
# Record found for the city: pevek
# Processing record 82 for the city: berlevag
# Record found for the city: berlevag
# Processing record 83 for the city: avera
# Record found for the city: avera
# Processing record 84 for the city: saint-philippe
# Record found for the city: saint-philippe
# Processing record 85 for the city: seoul
# Record found for the city: seoul
# Processing record 86 for the city: pechenga
# Record found for the city: pechenga
# Processing record 87 for the city: sentyabrskiy
# Data not found... skip.
# Processing record 88 for the city: aklavik
# Record found for the city: aklavik
# Processing record 89 for the city: madimba
# Record found for the city: madimba
# Processing record 90 for the city: khorramshahr
# Record found for the city: khorramshahr
# Processing record 91 for the city: itarema
# Record found for the city: itarema
# Processing record 92 for the city: east london
# Record found for the city: east london
# Processing record 93 for the city: sinnamary
# Record found for the city: sinnamary
# Processing record 94 for the city: kerteh
# Data not found... skip.
# Processing record 95 for the city: san patricio
# Record found for the city: san patricio
# Processing record 96 for the city: okha
# Record found for the city: okha
# Processing record 97 for the city: tecoanapa
# Record found for the city: tecoanapa
# Processing record 98 for the city: anadyr
# Record found for the city: anadyr
# Processing record 99 for the city: zhanaozen
# Record found for the city: zhanaozen
# Processing record 100 for the city: snezhnogorsk
# Record found for the city: snezhnogorsk
# Processing record 101 for the city: margate
# Record found for the city: margate
# Processing record 102 for the city: ponta do sol
# Record found for the city: ponta do sol
# Processing record 103 for the city: umzimvubu
# Data not found... skip.
# Processing record 104 for the city: nizhneyansk
# Data not found... skip.
# Processing record 105 for the city: grindavik
# Record found for the city: grindavik
# Processing record 106 for the city: saleaula
# Data not found... skip.
# Processing record 107 for the city: tiksi
# Record found for the city: tiksi
# Processing record 108 for the city: dali
# Record found for the city: dali
# Processing record 109 for the city: hithadhoo
# Record found for the city: hithadhoo
# Processing record 110 for the city: mys shmidta
# Data not found... skip.
# Processing record 111 for the city: cape town
# Record found for the city: cape town
# Processing record 112 for the city: arlit
# Record found for the city: arlit
# Processing record 113 for the city: conde
# Record found for the city: conde
# Processing record 114 for the city: synya
# Record found for the city: synya
# Processing record 115 for the city: punta gorda
# Record found for the city: punta gorda
# Processing record 116 for the city: shubarshi
# Record found for the city: shubarshi
# Processing record 117 for the city: west plains
# Record found for the city: west plains
# Processing record 118 for the city: great falls
# Record found for the city: great falls
# Processing record 119 for the city: yar-sale
# Record found for the city: yar-sale
# Processing record 120 for the city: limerick
# Record found for the city: limerick
# Processing record 121 for the city: dagua
# Record found for the city: dagua
# Processing record 122 for the city: sanmenxia
# Record found for the city: sanmenxia
# Processing record 123 for the city: arinos
# Record found for the city: arinos
# Processing record 124 for the city: fairbanks
# Record found for the city: fairbanks
# Processing record 125 for the city: lasa
# Record found for the city: lasa
# Processing record 126 for the city: san martin de hidalgo
# Data not found... skip.
# Processing record 127 for the city: guliston
# Record found for the city: guliston
# Processing record 128 for the city: saskylakh
# Record found for the city: saskylakh
# Processing record 129 for the city: klaksvik
# Record found for the city: klaksvik
# Processing record 130 for the city: tahta
# Record found for the city: tahta
# Processing record 131 for the city: bahia blanca
# Record found for the city: bahia blanca
# Processing record 132 for the city: provideniya
# Record found for the city: provideniya
# Processing record 133 for the city: kruisfontein
# Record found for the city: kruisfontein
# Processing record 134 for the city: chokurdakh
# Record found for the city: chokurdakh
# Processing record 135 for the city: bredasdorp
# Record found for the city: bredasdorp
# Processing record 136 for the city: yellowknife
# Record found for the city: yellowknife
# Processing record 137 for the city: linxia
# Record found for the city: linxia
# Processing record 138 for the city: haibowan
# Data not found... skip.
# Processing record 139 for the city: malpura
# Record found for the city: malpura
# Processing record 140 for the city: mareeba
# Record found for the city: mareeba
# Processing record 141 for the city: hilo
# Record found for the city: hilo
# Processing record 142 for the city: saldanha
# Record found for the city: saldanha
# Processing record 143 for the city: port-gentil
# Record found for the city: port-gentil
# Processing record 144 for the city: bati
# Record found for the city: bati
# Processing record 145 for the city: severo-yeniseyskiy
# Record found for the city: severo-yeniseyskiy
# Processing record 146 for the city: port elizabeth
# Record found for the city: port elizabeth
# Processing record 147 for the city: bani
# Record found for the city: bani
# Processing record 148 for the city: castro
# Record found for the city: castro
# Processing record 149 for the city: serafimovich
# Record found for the city: serafimovich
# Processing record 150 for the city: fallon
# Record found for the city: fallon
# Processing record 151 for the city: ancud
# Record found for the city: ancud
# Processing record 152 for the city: ribeira grande
# Record found for the city: ribeira grande
# Processing record 153 for the city: bulungu
# Record found for the city: bulungu
# Processing record 154 for the city: buon me thuot
# Data not found... skip.
# Processing record 155 for the city: sorland
# Record found for the city: sorland
# Processing record 156 for the city: bria
# Record found for the city: bria
# Processing record 157 for the city: coquimbo
# Record found for the city: coquimbo
# Processing record 158 for the city: rio grande
# Record found for the city: rio grande
# Processing record 159 for the city: hofn
# Record found for the city: hofn
# Processing record 160 for the city: otaki
# Record found for the city: otaki
# Processing record 161 for the city: ilulissat
# Record found for the city: ilulissat
# Processing record 162 for the city: labuan
# Record found for the city: labuan
# Processing record 163 for the city: opobo
# Data not found... skip.
# Processing record 164 for the city: thompson
# Record found for the city: thompson
# Processing record 165 for the city: elda
# Record found for the city: elda
# Processing record 166 for the city: khabary
# Record found for the city: khabary
# Processing record 167 for the city: butaritari
# Record found for the city: butaritari
# Processing record 168 for the city: malaya serdoba
# Record found for the city: malaya serdoba
# Processing record 169 for the city: husavik
# Record found for the city: husavik
# Processing record 170 for the city: gueret
# Record found for the city: gueret
# Processing record 171 for the city: bayburt
# Record found for the city: bayburt
# Processing record 172 for the city: ovre ardal
# Record found for the city: ovre ardal
# Processing record 173 for the city: tongren
# Record found for the city: tongren
# Processing record 174 for the city: aasiaat
# Record found for the city: aasiaat
# Processing record 175 for the city: vaitupu
# Data not found... skip.
# Processing record 176 for the city: khatanga
# Record found for the city: khatanga
# Processing record 177 for the city: tautira
# Record found for the city: tautira
# Processing record 178 for the city: madras
# Record found for the city: madras
# Processing record 179 for the city: tilichiki
# Record found for the city: tilichiki
# Processing record 180 for the city: ortona
# Record found for the city: ortona
# Processing record 181 for the city: kudahuvadhoo
# Record found for the city: kudahuvadhoo
# Processing record 182 for the city: mayor pablo lagerenza
# Record found for the city: mayor pablo lagerenza
# Processing record 183 for the city: luanda
# Record found for the city: luanda
# Processing record 184 for the city: homa bay
# Record found for the city: homa bay
# Processing record 185 for the city: nunkini
# Record found for the city: nunkini
# Processing record 186 for the city: puerto baquerizo moreno
# Record found for the city: puerto baquerizo moreno
# Processing record 187 for the city: doctor arroyo
# Record found for the city: doctor arroyo
# Processing record 188 for the city: khislavichi
# Record found for the city: khislavichi
# Processing record 189 for the city: petropavlovsk-kamchatskiy
# Record found for the city: petropavlovsk-kamchatskiy
# Processing record 190 for the city: tadine
# Record found for the city: tadine
# Processing record 191 for the city: huesca
# Record found for the city: huesca
# Processing record 192 for the city: georgetown
# Record found for the city: georgetown
# Processing record 193 for the city: san marcos de colon
# Record found for the city: san marcos de colon
# Processing record 194 for the city: boende
# Record found for the city: boende
# Processing record 195 for the city: cidreira
# Record found for the city: cidreira
# Processing record 196 for the city: lanxi
# Record found for the city: lanxi
# Processing record 197 for the city: zonguldak
# Record found for the city: zonguldak
# Processing record 198 for the city: tubruq
# Data not found... skip.
# Processing record 199 for the city: palmas de monte alto
# Record found for the city: palmas de monte alto
# Processing record 200 for the city: albania
# Record found for the city: albania
# Processing record 201 for the city: isangel
# Record found for the city: isangel
# Processing record 202 for the city: ixtapa
# Record found for the city: ixtapa
# Processing record 203 for the city: gawler
# Record found for the city: gawler
# Processing record 204 for the city: uusikaupunki
# Record found for the city: uusikaupunki
# Processing record 205 for the city: ambilobe
# Record found for the city: ambilobe
# Processing record 206 for the city: richards bay
# Record found for the city: richards bay
# Processing record 207 for the city: harper
# Record found for the city: harper
# Processing record 208 for the city: avarua
# Record found for the city: avarua
# Processing record 209 for the city: broken hill
# Record found for the city: broken hill
# Processing record 210 for the city: nchelenge
# Record found for the city: nchelenge
# Processing record 211 for the city: port alfred
# Record found for the city: port alfred
# Processing record 212 for the city: tome
# Record found for the city: tome
# Processing record 213 for the city: pangnirtung
# Record found for the city: pangnirtung
# Processing record 214 for the city: fushan
# Record found for the city: fushan
# Processing record 215 for the city: kamenskoye
# Data not found... skip.
# Processing record 216 for the city: sao joao da barra
# Record found for the city: sao joao da barra
# Processing record 217 for the city: aflu
# Data not found... skip.
# Processing record 218 for the city: chuy
# Record found for the city: chuy
# Processing record 219 for the city: lolua
# Data not found... skip.
# Processing record 220 for the city: leme
# Record found for the city: leme
# Processing record 221 for the city: emerald
# Record found for the city: emerald
# Processing record 222 for the city: takoradi
# Record found for the city: takoradi
# Processing record 223 for the city: vestmannaeyjar
# Record found for the city: vestmannaeyjar
# Processing record 224 for the city: koumac
# Record found for the city: koumac
# Processing record 225 for the city: klyuchi
# Record found for the city: klyuchi
# Processing record 226 for the city: faanui
# Record found for the city: faanui
# Processing record 227 for the city: beidao
# Record found for the city: beidao
# Processing record 228 for the city: yumen
# Record found for the city: yumen
# Processing record 229 for the city: cubara
# Record found for the city: cubara
# Processing record 230 for the city: abu samrah
# Record found for the city: abu samrah
# Processing record 231 for the city: primalkinskoye
# Record found for the city: primalkinskoye
# Processing record 232 for the city: troitsko-pechorsk
# Record found for the city: troitsko-pechorsk
# Processing record 233 for the city: altukhovo
# Record found for the city: altukhovo
# Processing record 234 for the city: kavieng
# Record found for the city: kavieng
# Processing record 235 for the city: leningradskiy
# Record found for the city: leningradskiy
# Processing record 236 for the city: college
# Record found for the city: college
# Processing record 237 for the city: udachnyy
# Record found for the city: udachnyy
# Processing record 238 for the city: zhirnovsk
# Record found for the city: zhirnovsk
# Processing record 239 for the city: svetlogorsk
# Record found for the city: svetlogorsk
# Processing record 240 for the city: riverton
# Record found for the city: riverton
# Processing record 241 for the city: sao filipe
# Record found for the city: sao filipe
# Processing record 242 for the city: port lincoln
# Record found for the city: port lincoln
# Processing record 243 for the city: terra santa
# Record found for the city: terra santa
# Processing record 244 for the city: hasaki
# Record found for the city: hasaki
# Processing record 245 for the city: charlottesville
# Record found for the city: charlottesville
# Processing record 246 for the city: alekseyevka
# Record found for the city: alekseyevka
# Processing record 247 for the city: lorengau
# Record found for the city: lorengau
# Processing record 248 for the city: mahebourg
# Record found for the city: mahebourg
# Processing record 249 for the city: amboasary
# Record found for the city: amboasary
# Processing record 250 for the city: bereda
# Record found for the city: bereda
# Processing record 251 for the city: viligili
# Data not found... skip.
# Processing record 252 for the city: naze
# Record found for the city: naze
# Processing record 253 for the city: yerbogachen
# Record found for the city: yerbogachen
# Processing record 254 for the city: veraval
# Record found for the city: veraval
# Processing record 255 for the city: munsingen
# Record found for the city: munsingen
# Processing record 256 for the city: grand river south east
# Data not found... skip.
# Processing record 257 for the city: caravelas
# Record found for the city: caravelas
# Processing record 258 for the city: hadejia
# Record found for the city: hadejia
# Processing record 259 for the city: ajaccio
# Record found for the city: ajaccio
# Processing record 260 for the city: kaitangata
# Record found for the city: kaitangata
# Processing record 261 for the city: vieques
# Record found for the city: vieques
# Processing record 262 for the city: marsala
# Record found for the city: marsala
# Processing record 263 for the city: salalah
# Record found for the city: salalah
# Processing record 264 for the city: cabo san lucas
# Record found for the city: cabo san lucas
# Processing record 265 for the city: kantemirovka
# Record found for the city: kantemirovka
# Processing record 266 for the city: koutiala
# Record found for the city: koutiala
# Processing record 267 for the city: elmira
# Record found for the city: elmira
# Processing record 268 for the city: tsihombe
# Data not found... skip.
# Processing record 269 for the city: baglung
# Record found for the city: baglung
# Processing record 270 for the city: tessalit
# Record found for the city: tessalit
# Processing record 271 for the city: viking
# Record found for the city: viking
# Processing record 272 for the city: yugo-kamskiy
# Record found for the city: yugo-kamskiy
# Processing record 273 for the city: sao felix do xingu
# Record found for the city: sao felix do xingu
# Processing record 274 for the city: nome
# Record found for the city: nome
# Processing record 275 for the city: luderitz
# Record found for the city: luderitz
# Processing record 276 for the city: makow mazowiecki
# Record found for the city: makow mazowiecki
# Processing record 277 for the city: awbari
# Record found for the city: awbari
# Processing record 278 for the city: samusu
# Data not found... skip.
# Processing record 279 for the city: beringovskiy
# Record found for the city: beringovskiy
# Processing record 280 for the city: presidencia roque saenz pena
# Record found for the city: presidencia roque saenz pena
# Processing record 281 for the city: longyearbyen
# Record found for the city: longyearbyen
# Processing record 282 for the city: komsomolskiy
# Record found for the city: komsomolskiy
# Processing record 283 for the city: port macquarie
# Record found for the city: port macquarie
# Processing record 284 for the city: nouadhibou
# Record found for the city: nouadhibou
# Processing record 285 for the city: karatuzskoye
# Record found for the city: karatuzskoye
# Processing record 286 for the city: ritchie
# Record found for the city: ritchie
# Processing record 287 for the city: sambava
# Record found for the city: sambava
# Processing record 288 for the city: deep river
# Record found for the city: deep river
# Processing record 289 for the city: la uribe
# Data not found... skip.
# Processing record 290 for the city: adeje
# Record found for the city: adeje
# Processing record 291 for the city: puerto escondido
# Record found for the city: puerto escondido
# Processing record 292 for the city: lunenburg
# Record found for the city: lunenburg
# Processing record 293 for the city: nizip
# Record found for the city: nizip
# Processing record 294 for the city: ayoquezco
# Data not found... skip.
# Processing record 295 for the city: fort smith
# Record found for the city: fort smith
# Processing record 296 for the city: barahona
# Record found for the city: barahona
# Processing record 297 for the city: batavia
# Record found for the city: batavia
# Processing record 298 for the city: kawalu
# Record found for the city: kawalu
# Processing record 299 for the city: ust-nera
# Record found for the city: ust-nera
# Processing record 300 for the city: pitimbu
# Record found for the city: pitimbu
# Processing record 301 for the city: saint-georges
# Record found for the city: saint-georges
# Processing record 302 for the city: jalu
# Record found for the city: jalu
# Processing record 303 for the city: teya
# Record found for the city: teya
# Processing record 304 for the city: kalevala
# Record found for the city: kalevala
# Processing record 305 for the city: mandalgovi
# Record found for the city: mandalgovi
# Processing record 306 for the city: rawannawi
# Data not found... skip.
# Processing record 307 for the city: yala
# Record found for the city: yala
# Processing record 308 for the city: shimoda
# Record found for the city: shimoda
# Processing record 309 for the city: lumsden
# Record found for the city: lumsden
# Processing record 310 for the city: corn island
# Record found for the city: corn island
# Processing record 311 for the city: kyzyl-suu
# Record found for the city: kyzyl-suu
# Processing record 312 for the city: san jose
# Record found for the city: san jose
# Processing record 313 for the city: celestun
# Record found for the city: celestun
# Processing record 314 for the city: kahului
# Record found for the city: kahului
# Processing record 315 for the city: vila velha
# Record found for the city: vila velha
# Processing record 316 for the city: trofors
# Record found for the city: trofors
# Processing record 317 for the city: inderborskiy
# Data not found... skip.
# Processing record 318 for the city: hantsport
# Record found for the city: hantsport
# Processing record 319 for the city: general pico
# Record found for the city: general pico
# Processing record 320 for the city: novobiryusinskiy
# Record found for the city: novobiryusinskiy
# Processing record 321 for the city: boa vista
# Record found for the city: boa vista
# Processing record 322 for the city: amderma
# Data not found... skip.
# Processing record 323 for the city: aksarka
# Record found for the city: aksarka
# Processing record 324 for the city: shenjiamen
# Record found for the city: shenjiamen
# Processing record 325 for the city: formosa
# Record found for the city: formosa
# Processing record 326 for the city: igurusi
# Record found for the city: igurusi
# Processing record 327 for the city: fare
# Record found for the city: fare
# Processing record 328 for the city: samarai
# Record found for the city: samarai
# Processing record 329 for the city: antalaha
# Record found for the city: antalaha
# Processing record 330 for the city: wahran
# Data not found... skip.
# Processing record 331 for the city: flinders
# Record found for the city: flinders
# Processing record 332 for the city: qui nhon
# Record found for the city: qui nhon
# Processing record 333 for the city: sioux lookout
# Record found for the city: sioux lookout
# Processing record 334 for the city: deputatskiy
# Record found for the city: deputatskiy
# Processing record 335 for the city: talcahuano
# Record found for the city: talcahuano
# Processing record 336 for the city: camacha
# Record found for the city: camacha
# Processing record 337 for the city: birao
# Record found for the city: birao
# Processing record 338 for the city: puerto carreno
# Record found for the city: puerto carreno
# Processing record 339 for the city: shiloh
# Record found for the city: shiloh
# Processing record 340 for the city: inuvik
# Record found for the city: inuvik
# Processing record 341 for the city: nikolskoye
# Record found for the city: nikolskoye
# Processing record 342 for the city: cervo
# Record found for the city: cervo
# Processing record 343 for the city: namibe
# Record found for the city: namibe
# Processing record 344 for the city: palmer
# Record found for the city: palmer
# Processing record 345 for the city: asau
# Record found for the city: asau
# Processing record 346 for the city: kolpashevo
# Record found for the city: kolpashevo
# Processing record 347 for the city: cabreuva
# Record found for the city: cabreuva
# Processing record 348 for the city: buta
# Record found for the city: buta
# Processing record 349 for the city: fortuna
# Record found for the city: fortuna
# Processing record 350 for the city: luba
# Record found for the city: luba
# Processing record 351 for the city: zyryanka
# Record found for the city: zyryanka
# Processing record 352 for the city: matamoros
# Record found for the city: matamoros
# Processing record 353 for the city: hamilton
# Record found for the city: hamilton
# Processing record 354 for the city: los llanos de aridane
# Record found for the city: los llanos de aridane
# Processing record 355 for the city: muncar
# Record found for the city: muncar
# Processing record 356 for the city: norman wells
# Record found for the city: norman wells
# Processing record 357 for the city: vallenar
# Record found for the city: vallenar
# Processing record 358 for the city: vardo
# Record found for the city: vardo
# Processing record 359 for the city: teguise
# Record found for the city: teguise
# Processing record 360 for the city: wulanhaote
# Data not found... skip.
# Processing record 361 for the city: belaya gora
# Record found for the city: belaya gora
# Processing record 362 for the city: marsaxlokk
# Record found for the city: marsaxlokk
# Processing record 363 for the city: alofi
# Record found for the city: alofi
# Processing record 364 for the city: esperance
# Record found for the city: esperance
# Processing record 365 for the city: eenhana
# Record found for the city: eenhana
# Processing record 366 for the city: sola
# Record found for the city: sola
# Processing record 367 for the city: iskateley
# Record found for the city: iskateley
# Processing record 368 for the city: tasiilaq
# Record found for the city: tasiilaq
# Processing record 369 for the city: bathsheba
# Record found for the city: bathsheba
# Processing record 370 for the city: carnarvon
# Record found for the city: carnarvon
# Processing record 371 for the city: sirur
# Record found for the city: sirur
# Processing record 372 for the city: tuktoyaktuk
# Record found for the city: tuktoyaktuk
# Processing record 373 for the city: plettenberg bay
# Record found for the city: plettenberg bay
# Processing record 374 for the city: maniwaki
# Record found for the city: maniwaki
# Processing record 375 for the city: redmond
# Record found for the city: redmond
# Processing record 376 for the city: kinston
# Record found for the city: kinston
# Processing record 377 for the city: lubliniec
# Record found for the city: lubliniec
# Processing record 378 for the city: huarmey
# Record found for the city: huarmey
# Processing record 379 for the city: zolotinka
# Data not found... skip.
# Processing record 380 for the city: casino
# Record found for the city: casino
# Processing record 381 for the city: hurricane
# Record found for the city: hurricane
# Processing record 382 for the city: zhanatas
# Data not found... skip.
# Processing record 383 for the city: bodden town
# Record found for the city: bodden town
# Processing record 384 for the city: silver city
# Record found for the city: silver city
# Processing record 385 for the city: russell
# Record found for the city: russell
# Processing record 386 for the city: tuatapere
# Record found for the city: tuatapere
# Processing record 387 for the city: toliary
# Data not found... skip.
# Processing record 388 for the city: kaoma
# Record found for the city: kaoma
# Processing record 389 for the city: bengkulu
# Record found for the city: bengkulu
# Processing record 390 for the city: christchurch
# Record found for the city: christchurch
# Processing record 391 for the city: pingzhuang
# Record found for the city: pingzhuang
# Processing record 392 for the city: coaldale
# Record found for the city: coaldale
# Processing record 393 for the city: dodge city
# Record found for the city: dodge city
# Processing record 394 for the city: waddan
# Record found for the city: waddan
# Processing record 395 for the city: hongjiang
# Record found for the city: hongjiang
# Processing record 396 for the city: mutare
# Record found for the city: mutare
# Processing record 397 for the city: kutum
# Record found for the city: kutum
# Processing record 398 for the city: kirakira
# Record found for the city: kirakira
# Processing record 399 for the city: temaraia
# Data not found... skip.
# Processing record 400 for the city: toro
# Record found for the city: toro
# Processing record 401 for the city: egvekinot
# Record found for the city: egvekinot
# Processing record 402 for the city: satitoa
# Data not found... skip.
# Processing record 403 for the city: waipawa
# Record found for the city: waipawa
# Processing record 404 for the city: linqiong
# Record found for the city: linqiong
# Processing record 405 for the city: redlands
# Record found for the city: redlands
# Processing record 406 for the city: fivizzano
# Record found for the city: fivizzano
# Processing record 407 for the city: belyy yar
# Record found for the city: belyy yar
# Processing record 408 for the city: vila
# Record found for the city: vila
# Processing record 409 for the city: cockburn town
# Record found for the city: cockburn town
# Processing record 410 for the city: padang
# Record found for the city: padang
# Processing record 411 for the city: ponta delgada
# Record found for the city: ponta delgada
# Processing record 412 for the city: warqla
# Data not found... skip.
# Processing record 413 for the city: glenwood springs
# Record found for the city: glenwood springs
# Processing record 414 for the city: paamiut
# Record found for the city: paamiut
# Processing record 415 for the city: areosa
# Record found for the city: areosa
# Processing record 416 for the city: maragogi
# Record found for the city: maragogi
# Processing record 417 for the city: isla mujeres
# Record found for the city: isla mujeres
# Processing record 418 for the city: asilah
# Record found for the city: asilah
# Processing record 419 for the city: dudinka
# Record found for the city: dudinka
# Processing record 420 for the city: burica
# Data not found... skip.
# Processing record 421 for the city: mingyue
# Record found for the city: mingyue
# Processing record 422 for the city: bilma
# Record found for the city: bilma
# Processing record 423 for the city: beatrice
# Record found for the city: beatrice
# Processing record 424 for the city: ossora
# Record found for the city: ossora
# Processing record 425 for the city: suez
# Record found for the city: suez
# Processing record 426 for the city: palauig
# Record found for the city: palauig
# Processing record 427 for the city: inhambane
# Record found for the city: inhambane
# Processing record 428 for the city: rio cauto
# Record found for the city: rio cauto
# Processing record 429 for the city: tromso
# Record found for the city: tromso
# Processing record 430 for the city: coihaique
# Record found for the city: coihaique
# Processing record 431 for the city: north bend
# Record found for the city: north bend
# Processing record 432 for the city: zarasai
# Record found for the city: zarasai
# Processing record 433 for the city: andevoranto
# Data not found... skip.
# Processing record 434 for the city: rostaq
# Data not found... skip.
# Processing record 435 for the city: derzhavinsk
# Record found for the city: derzhavinsk
# Processing record 436 for the city: kaka
# Record found for the city: kaka
# Processing record 437 for the city: camopi
# Record found for the city: camopi
# Processing record 438 for the city: salym
# Record found for the city: salym
# Processing record 439 for the city: sitka
# Record found for the city: sitka
# Processing record 440 for the city: hami
# Record found for the city: hami
# Processing record 441 for the city: verkhnevilyuysk
# Record found for the city: verkhnevilyuysk
# Processing record 442 for the city: tabou
# Record found for the city: tabou
# Processing record 443 for the city: sorvag
# Data not found... skip.
# Processing record 444 for the city: kloulklubed
# Record found for the city: kloulklubed
# Processing record 445 for the city: murray bridge
# Record found for the city: murray bridge
# Processing record 446 for the city: sao joao batista
# Record found for the city: sao joao batista
# Processing record 447 for the city: hambantota
# Record found for the city: hambantota
# Processing record 448 for the city: fiche
# Record found for the city: fiche
# Processing record 449 for the city: xingtai
# Record found for the city: xingtai
# Processing record 450 for the city: daru
# Record found for the city: daru
# Processing record 451 for the city: mehamn
# Record found for the city: mehamn
# Processing record 452 for the city: haines junction
# Record found for the city: haines junction
# Processing record 453 for the city: erdenet
# Record found for the city: erdenet
# Processing record 454 for the city: guerrero negro
# Record found for the city: guerrero negro
# Processing record 455 for the city: barcelos
# Record found for the city: barcelos
# Processing record 456 for the city: port-cartier
# Record found for the city: port-cartier
# Processing record 457 for the city: ca mau
# Record found for the city: ca mau
# Processing record 458 for the city: lubumbashi
# Record found for the city: lubumbashi
# Processing record 459 for the city: iskitim
# Record found for the city: iskitim
# Processing record 460 for the city: itsukaichi
# Record found for the city: itsukaichi
# Processing record 461 for the city: vejprty
# Record found for the city: vejprty
# Processing record 462 for the city: port hardy
# Record found for the city: port hardy
# Processing record 463 for the city: havre
# Record found for the city: havre
# Processing record 464 for the city: mount gambier
# Record found for the city: mount gambier
# Processing record 465 for the city: nemuro
# Record found for the city: nemuro
# Processing record 466 for the city: novyy urengoy
# Record found for the city: novyy urengoy
# Processing record 467 for the city: lompoc
# Record found for the city: lompoc
# Processing record 468 for the city: phan rang
# Data not found... skip.
# Processing record 469 for the city: launceston
# Record found for the city: launceston
# Processing record 470 for the city: sampit
# Record found for the city: sampit
# Processing record 471 for the city: adre
# Record found for the city: adre
# Processing record 472 for the city: howard springs
# Record found for the city: howard springs
# Processing record 473 for the city: sibu
# Record found for the city: sibu
# Processing record 474 for the city: rancho palos verdes
# Record found for the city: rancho palos verdes
# Processing record 475 for the city: tsabong
# Record found for the city: tsabong
# Processing record 476 for the city: amga
# Record found for the city: amga
# Processing record 477 for the city: poum
# Record found for the city: poum
# Processing record 478 for the city: kununurra
# Record found for the city: kununurra
# Processing record 479 for the city: beloha
# Record found for the city: beloha
# Processing record 480 for the city: lamu
# Record found for the city: lamu
# Processing record 481 for the city: bairiki
# Record found for the city: bairiki
# Processing record 482 for the city: bonavista
# Record found for the city: bonavista
# Processing record 483 for the city: ubinskoye
# Record found for the city: ubinskoye
# Processing record 484 for the city: ojinaga
# Record found for the city: ojinaga
# Processing record 485 for the city: lahij
# Record found for the city: lahij
# Processing record 486 for the city: phuthaditjhaba
# Record found for the city: phuthaditjhaba
# Processing record 487 for the city: moba
# Record found for the city: moba
# Processing record 488 for the city: petauke
# Record found for the city: petauke
# Processing record 489 for the city: gashua
# Record found for the city: gashua
# Processing record 490 for the city: codrington
# Record found for the city: codrington
# Processing record 491 for the city: fort wellington
# Record found for the city: fort wellington
# Processing record 492 for the city: mar del plata
# Record found for the city: mar del plata
# Processing record 493 for the city: kamenka
# Record found for the city: kamenka
# Processing record 494 for the city: nelson bay
# Record found for the city: nelson bay
# Processing record 495 for the city: quelimane
# Record found for the city: quelimane
# Processing record 496 for the city: santa maria
# Record found for the city: santa maria
# Processing record 497 for the city: kavaratti
# Record found for the city: kavaratti
# Processing record 498 for the city: tocopilla
# Record found for the city: tocopilla
# Processing record 499 for the city: rodas
# Record found for the city: rodas
# Processing record 500 for the city: agadez
# Record found for the city: agadez
# Processing record 501 for the city: mamboma
# Record found for the city: mamboma
# Processing record 502 for the city: port keats
# Record found for the city: port keats
# Processing record 503 for the city: katima mulilo
# Record found for the city: katima mulilo
# Processing record 504 for the city: ilhabela
# Record found for the city: ilhabela
# Processing record 505 for the city: moskovskiy
# Record found for the city: moskovskiy
# Processing record 506 for the city: erenhot
# Record found for the city: erenhot
# Processing record 507 for the city: whitehorse
# Record found for the city: whitehorse
# Processing record 508 for the city: tual
# Record found for the city: tual
# Processing record 509 for the city: jati
# Record found for the city: jati
# Processing record 510 for the city: banda aceh
# Record found for the city: banda aceh
# Processing record 511 for the city: sao jose da coroa grande
# Record found for the city: sao jose da coroa grande
# Processing record 512 for the city: la esperanza
# Record found for the city: la esperanza
# Processing record 513 for the city: balabac
# Record found for the city: balabac
# Processing record 514 for the city: henties bay
# Record found for the city: henties bay
# Processing record 515 for the city: gazanjyk
# Record found for the city: gazanjyk
# Processing record 516 for the city: nuuk
# Record found for the city: nuuk
# Processing record 517 for the city: mildura
# Record found for the city: mildura
# Processing record 518 for the city: robertsport
# Record found for the city: robertsport
# Processing record 519 for the city: mzimba
# Record found for the city: mzimba
# Processing record 520 for the city: puerto del rosario
# Record found for the city: puerto del rosario
# Processing record 521 for the city: rapid valley
# Record found for the city: rapid valley
# Processing record 522 for the city: lavrentiya
# Record found for the city: lavrentiya
# Processing record 523 for the city: barranca
# Record found for the city: barranca
# Processing record 524 for the city: timbiqui
# Record found for the city: timbiqui
# Processing record 525 for the city: neiafu
# Record found for the city: neiafu
# Processing record 526 for the city: nanortalik
# Record found for the city: nanortalik
# Processing record 527 for the city: tutoia
# Record found for the city: tutoia
# Processing record 528 for the city: bay saint louis
# Record found for the city: bay saint louis
# Processing record 529 for the city: meulaboh
# Record found for the city: meulaboh
# Processing record 530 for the city: mitoc
# Record found for the city: mitoc
# Processing record 531 for the city: windhoek
# Record found for the city: windhoek
# Processing record 532 for the city: praia
# Record found for the city: praia
# Processing record 533 for the city: ostrovnoy
# Record found for the city: ostrovnoy
# Processing record 534 for the city: kefar tavor
# Record found for the city: kefar tavor
# Processing record 535 for the city: santiago
# Record found for the city: santiago
# Processing record 536 for the city: necochea
# Record found for the city: necochea
# Processing record 537 for the city: carballo
# Record found for the city: carballo
# Processing record 538 for the city: de aar
# Record found for the city: de aar
# Processing record 539 for the city: sarankhola
# Record found for the city: sarankhola
# Processing record 540 for the city: nizwa
# Record found for the city: nizwa
# Processing record 541 for the city: yandoon
# Data not found... skip.
# Processing record 542 for the city: umm lajj
# Record found for the city: umm lajj
# Processing record 543 for the city: vasai
# Record found for the city: vasai
# Processing record 544 for the city: buala
# Record found for the city: buala
# Processing record 545 for the city: buenos aires
# Record found for the city: buenos aires
# Processing record 546 for the city: triesen
# Record found for the city: triesen
# Processing record 547 for the city: huangpu
# Record found for the city: huangpu
# Processing record 548 for the city: pleshanovo
# Record found for the city: pleshanovo
# Processing record 549 for the city: klobuck
# Record found for the city: klobuck
# Processing record 550 for the city: rawson
# Record found for the city: rawson
# Processing record 551 for the city: lokosovo
# Record found for the city: lokosovo
# Processing record 552 for the city: port hawkesbury
# Record found for the city: port hawkesbury
# Processing record 553 for the city: campbell river
# Record found for the city: campbell river
# Processing record 554 for the city: opuwo
# Record found for the city: opuwo
# Processing record 555 for the city: bowral
# Record found for the city: bowral
# Processing record 556 for the city: jumla
# Record found for the city: jumla
# Processing record 557 for the city: omsukchan
# Record found for the city: omsukchan
# Processing record 558 for the city: tuma
# Record found for the city: tuma
# Processing record 559 for the city: cabildo
# Record found for the city: cabildo
# Processing record 560 for the city: olafsvik
# Record found for the city: olafsvik
# Processing record 561 for the city: alyangula
# Record found for the city: alyangula
# Processing record 562 for the city: westport
# Record found for the city: westport
# Processing record 563 for the city: soanierana ivongo
# Record found for the city: soanierana ivongo
# Processing record 564 for the city: merauke
# Record found for the city: merauke
# Processing record 565 for the city: hobyo
# Record found for the city: hobyo
# Processing record 566 for the city: hays
# Record found for the city: hays
# Processing record 567 for the city: xam nua
# Record found for the city: xam nua
# Processing record 568 for the city: oyama
# Record found for the city: oyama
# Processing record 569 for the city: prince rupert
# Record found for the city: prince rupert
# Processing record 570 for the city: wana
# Record found for the city: wana
# Processing record 571 for the city: okitipupa
# Record found for the city: okitipupa
# Processing record 572 for the city: zarand
# Record found for the city: zarand
# Processing record 573 for the city: marystown
# Record found for the city: marystown
# Processing record 574 for the city: touros
# Record found for the city: touros
# Processing record 575 for the city: roald
# Record found for the city: roald
# Processing record 576 for the city: ust-kut
# Record found for the city: ust-kut
# Processing record 577 for the city: cayenne
# Record found for the city: cayenne
# Processing record 578 for the city: charters towers
# Record found for the city: charters towers
# Processing record 579 for the city: scunthorpe
# Record found for the city: scunthorpe
# Processing record 580 for the city: ayia galini
# Record found for the city: ayia galini
# Processing record 581 for the city: srimushnam
# Record found for the city: srimushnam
# Processing record 582 for the city: qasigiannguit
# Record found for the city: qasigiannguit
# Processing record 583 for the city: tigzirt
# Record found for the city: tigzirt
# Processing record 584 for the city: yomou
# Record found for the city: yomou
# Processing record 585 for the city: anito
# Record found for the city: anito
# Processing record 586 for the city: susanville
# Record found for the city: susanville
# Processing record 587 for the city: srednekolymsk
# Record found for the city: srednekolymsk
# Processing record 588 for the city: salinas
# Record found for the city: salinas
# Processing record 589 for the city: karakendzha
# Data not found... skip.
# Processing record 590 for the city: jambi
# Record found for the city: jambi
# Processing record 591 for the city: umm kaddadah
# Record found for the city: umm kaddadah
# Processing record 592 for the city: ahipara
# Record found for the city: ahipara
# Processing record 593 for the city: freising
# Record found for the city: freising
# Processing record 594 for the city: hengshui
# Record found for the city: hengshui
# Processing record 595 for the city: samalaeulu
# Data not found... skip.
# Processing record 596 for the city: tekeli
# Record found for the city: tekeli
# Processing record 597 for the city: alice springs
# Record found for the city: alice springs
# Processing record 598 for the city: yantal
# Record found for the city: yantal
# Processing record 599 for the city: ewa beach
# Record found for the city: ewa beach
# Processing record 600 for the city: zhanakorgan
# Record found for the city: zhanakorgan
# Processing record 601 for the city: lumby
# Record found for the city: lumby
# Processing record 602 for the city: vao
# Record found for the city: vao
# Processing record 603 for the city: canals
# Record found for the city: canals
# Processing record 604 for the city: santa isabel do rio negro
# Record found for the city: santa isabel do rio negro
# Processing record 605 for the city: nogliki
# Record found for the city: nogliki
# Processing record 606 for the city: leh
# Record found for the city: leh
# Processing record 607 for the city: astana
# Record found for the city: astana
# Processing record 608 for the city: taoudenni
# Record found for the city: taoudenni
# Processing record 609 for the city: digri
# Record found for the city: digri
# Processing record 610 for the city: ust-kuyga
# Record found for the city: ust-kuyga
# Processing record 611 for the city: ambodifototra
# Data not found... skip.
# Processing record 612 for the city: roma
# Record found for the city: roma
# Processing record 613 for the city: tongchuan
# Record found for the city: tongchuan
# Processing record 614 for the city: faya
# Record found for the city: faya
# Processing record 615 for the city: cortez
# Record found for the city: cortez
# Processing record 616 for the city: petrolina
# Record found for the city: petrolina
# Processing record 617 for the city: rumuruti
# Record found for the city: rumuruti
# Processing record 618 for the city: salta
# Record found for the city: salta
# Processing record 619 for the city: bosaso
# Record found for the city: bosaso
# Processing record 620 for the city: shyryayeve
# Record found for the city: shyryayeve
# Processing record 621 for the city: san vicente
# Record found for the city: san vicente
# Processing record 622 for the city: atambua
# Record found for the city: atambua
# Processing record 623 for the city: mosquera
# Record found for the city: mosquera
# Processing record 624 for the city: zapolyarnyy
# Record found for the city: zapolyarnyy
# Processing record 625 for the city: balkanabat
# Record found for the city: balkanabat
# Processing record 626 for the city: lyubech
# Record found for the city: lyubech
# Processing record 627 for the city: pasni
# Record found for the city: pasni
# Processing record 628 for the city: trat
# Record found for the city: trat
# Processing record 629 for the city: lure
# Record found for the city: lure
# Processing record 630 for the city: shekhupura
# Record found for the city: shekhupura
# Processing record 631 for the city: gorno-chuyskiy
# Data not found... skip.
# Processing record 632 for the city: manta
# Record found for the city: manta
# Processing record 633 for the city: dunedin
# Record found for the city: dunedin
# Processing record 634 for the city: svetlaya
# Record found for the city: svetlaya
# Processing record 635 for the city: evensk
# Record found for the city: evensk
# Processing record 636 for the city: tezu
# Record found for the city: tezu
# Processing record 637 for the city: maracaibo
# Record found for the city: maracaibo
# Processing record 638 for the city: matamba
# Record found for the city: matamba
# Processing record 639 for the city: dzerzhinsk
# Record found for the city: dzerzhinsk
# Processing record 640 for the city: perth
# Record found for the city: perth
# Processing record 641 for the city: acajutla
# Record found for the city: acajutla
# Processing record 642 for the city: verkhnetulomskiy
# Record found for the city: verkhnetulomskiy
# Processing record 643 for the city: eskil
# Record found for the city: eskil
# Processing record 644 for the city: tarcau
# Record found for the city: tarcau
# Processing record 645 for the city: chivilcoy
# Record found for the city: chivilcoy
# Processing record 646 for the city: houma
# Record found for the city: houma
# Processing record 647 for the city: aguada de pasajeros
# Record found for the city: aguada de pasajeros
# Processing record 648 for the city: malakal
# Record found for the city: malakal
# Processing record 649 for the city: santiago de cao
# Record found for the city: santiago de cao
# Processing record 650 for the city: ngukurr
# Data not found... skip.
# Processing record 651 for the city: oksfjord
# Record found for the city: oksfjord
# Processing record 652 for the city: andilamena
# Record found for the city: andilamena
# Processing record 653 for the city: tshikapa
# Record found for the city: tshikapa
# Processing record 654 for the city: te anau
# Record found for the city: te anau
# Processing record 655 for the city: pochutla
# Record found for the city: pochutla
# Processing record 656 for the city: manzhouli
# Record found for the city: manzhouli
# Processing record 657 for the city: pervomayskoye
# Record found for the city: pervomayskoye
# Processing record 658 for the city: miles city
# Record found for the city: miles city
# Processing record 659 for the city: khash
# Record found for the city: khash
# Processing record 660 for the city: scottsburgh
# Data not found... skip.
# Processing record 661 for the city: najran
# Record found for the city: najran
# Processing record 662 for the city: erzin
# Record found for the city: erzin
# Processing record 663 for the city: glens falls
# Record found for the city: glens falls
# Processing record 664 for the city: hammerfest
# Record found for the city: hammerfest
# Processing record 665 for the city: shaoguan
# Record found for the city: shaoguan
# Processing record 666 for the city: san policarpo
# Record found for the city: san policarpo
# Processing record 667 for the city: rangapara
# Record found for the city: rangapara
# Processing record 668 for the city: saint-denis
# Record found for the city: saint-denis
# Processing record 669 for the city: trairi
# Record found for the city: trairi
# Processing record 670 for the city: tura
# Record found for the city: tura
# Processing record 671 for the city: mwene-ditu
# Record found for the city: mwene-ditu
# Processing record 672 for the city: tiarei
# Record found for the city: tiarei
# Processing record 673 for the city: zhuhai
# Record found for the city: zhuhai
# Processing record 674 for the city: puerto lopez
# Record found for the city: puerto lopez
# Processing record 675 for the city: krasnoselkup
# Record found for the city: krasnoselkup
# Processing record 676 for the city: xichang
# Record found for the city: xichang
# Processing record 677 for the city: riyadh
# Record found for the city: riyadh
# Processing record 678 for the city: sagaing
# Record found for the city: sagaing
# Processing record 679 for the city: gyulahaza
# Record found for the city: gyulahaza
# Processing record 680 for the city: ous
# Record found for the city: ous
# Processing record 681 for the city: indianola
# Record found for the city: indianola
# Processing record 682 for the city: tabiauea
# Data not found... skip.
# Processing record 683 for the city: concepcion del oro
# Record found for the city: concepcion del oro
# Processing record 684 for the city: iroquois falls
# Record found for the city: iroquois falls
# Processing record 685 for the city: creston
# Record found for the city: creston
# Processing record 686 for the city: kathu
# Record found for the city: kathu
# Processing record 687 for the city: tirumullaivasal
# Record found for the city: tirumullaivasal
# Processing record 688 for the city: zabid
# Record found for the city: zabid
# Processing record 689 for the city: gigmoto
# Record found for the city: gigmoto
# Processing record 690 for the city: eureka
# Record found for the city: eureka
# Processing record 691 for the city: huamachuco
# Record found for the city: huamachuco
# Processing record 692 for the city: bilibino
# Record found for the city: bilibino
# Processing record 693 for the city: chenghai
# Record found for the city: chenghai
# Processing record 694 for the city: gorontalo
# Record found for the city: gorontalo
# Processing record 695 for the city: oussouye
# Record found for the city: oussouye
# Processing record 696 for the city: nampa
# Record found for the city: nampa
# Processing record 697 for the city: doha
# Record found for the city: doha
# Processing record 698 for the city: kjollefjord
# Record found for the city: kjollefjord
# Processing record 699 for the city: kaupanger
# Record found for the city: kaupanger
# Processing record 700 for the city: butembo
# Record found for the city: butembo
# Processing record 701 for the city: soe
# Record found for the city: soe
# Processing record 702 for the city: luau
# Record found for the city: luau
# Processing record 703 for the city: doctor pedro p. pena
# Data not found... skip.
# Processing record 704 for the city: basco
# Record found for the city: basco
# Processing record 705 for the city: dharchula
# Record found for the city: dharchula
# Processing record 706 for the city: virginia beach
# Record found for the city: virginia beach
# Processing record 707 for the city: acuexcomac
# Record found for the city: acuexcomac
# Processing record 708 for the city: azimur
# Data not found... skip.
# Processing record 709 for the city: buraydah
# Record found for the city: buraydah
# Processing record 710 for the city: shush
# Record found for the city: shush
# Processing record 711 for the city: kenai
# Record found for the city: kenai
# Processing record 712 for the city: pisco
# Record found for the city: pisco
# Processing record 713 for the city: kachiry
# Record found for the city: kachiry
# Processing record 714 for the city: toamasina
# Record found for the city: toamasina
# Processing record 715 for the city: nynashamn
# Record found for the city: nynashamn
# Processing record 716 for the city: dakar
# Record found for the city: dakar
# Processing record 717 for the city: utiroa
# Data not found... skip.
# Processing record 718 for the city: harindanga
# Record found for the city: harindanga
# Processing record 719 for the city: mascota
# Record found for the city: mascota
# Processing record 720 for the city: saryshagan
# Data not found... skip.
# Processing record 721 for the city: dingle
# Record found for the city: dingle
# Processing record 722 for the city: mithimna
# Data not found... skip.
# Processing record 723 for the city: pendleton
# Record found for the city: pendleton
# Processing record 724 for the city: poronaysk
# Record found for the city: poronaysk
# Processing record 725 for the city: nyurba
# Record found for the city: nyurba
# Processing record 726 for the city: yicheng
# Record found for the city: yicheng
# Processing record 727 for the city: jacinto city
# Record found for the city: jacinto city
# Processing record 728 for the city: hualmay
# Record found for the city: hualmay
# Processing record 729 for the city: mataram
# Record found for the city: mataram
# Processing record 730 for the city: sinjah
# Data not found... skip.
# Processing record 731 for the city: pangkalanbuun
# Record found for the city: pangkalanbuun
# Processing record 732 for the city: tomaszow lubelski
# Record found for the city: tomaszow lubelski
# Processing record 733 for the city: mana
# Record found for the city: mana
# Processing record 734 for the city: alugan
# Record found for the city: alugan
# Processing record 735 for the city: santiago del estero
# Record found for the city: santiago del estero
# Processing record 736 for the city: guanica
# Record found for the city: guanica
# Processing record 737 for the city: lewiston
# Record found for the city: lewiston
# Processing record 738 for the city: uray
# Record found for the city: uray
# Processing record 739 for the city: liwonde
# Record found for the city: liwonde
# Processing record 740 for the city: matara
# Record found for the city: matara
# Processing record 741 for the city: hokitika
# Record found for the city: hokitika
# Processing record 742 for the city: lixourion
# Record found for the city: lixourion
# Processing record 743 for the city: paso de patria
# Record found for the city: paso de patria
# Processing record 744 for the city: mabaruma
# Record found for the city: mabaruma
# Processing record 745 for the city: pokhara
# Record found for the city: pokhara
# Processing record 746 for the city: qunduz
# Record found for the city: qunduz
# Processing record 747 for the city: chapais
# Record found for the city: chapais
# Processing record 748 for the city: tiznit
# Record found for the city: tiznit
# Processing record 749 for the city: nizhneudinsk
# Record found for the city: nizhneudinsk
# Processing record 750 for the city: ballina
# Record found for the city: ballina
# Processing record 751 for the city: bentiu
# Record found for the city: bentiu
# Processing record 752 for the city: gat
# Record found for the city: gat
# Processing record 753 for the city: umarkot
# Record found for the city: umarkot
# Processing record 754 for the city: santa maria do suacui
# Record found for the city: santa maria do suacui
# Processing record 755 for the city: toamua
# Data not found... skip.
# Processing record 756 for the city: troitskoye
# Record found for the city: troitskoye
# Processing record 757 for the city: gamba
# Record found for the city: gamba
# Processing record 758 for the city: santa cruz
# Record found for the city: santa cruz
# Processing record 759 for the city: malaya purga
# Record found for the city: malaya purga
# Processing record 760 for the city: tateyama
# Record found for the city: tateyama
# Processing record 761 for the city: barawe
# Data not found... skip.
# Processing record 762 for the city: pindiga
# Record found for the city: pindiga
# Processing record 763 for the city: bichura
# Record found for the city: bichura
# Processing record 764 for the city: ayan
# Record found for the city: ayan
# Processing record 765 for the city: balkhash
# Record found for the city: balkhash
# Processing record 766 for the city: ketchikan
# Record found for the city: ketchikan
# Processing record 767 for the city: mopti
# Record found for the city: mopti
# Processing record 768 for the city: buchanan
# Record found for the city: buchanan

# %%
# Run Count to see how many records were found

len(city)
# Out:
# 708

# %%
# Create dataframe
weather_dict = {
    "City": city,
    "Country": country,
    "Lat": lat,
    "Lng": lon,
    "Max Temp": temp,
    "Humidity": humid,
    "Cloudiness": cloud,
    "Wind Speed": wind,
    "Current Description": description
}

weatherPy_Database = pd.DataFrame(weather_dict)
weatherPy_Database.head(10)
# Out:
#                  City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Acapulco de Juárez      MX  16.86  -99.89     82.40        83          40
# 1              Albany      US  42.60  -73.97     34.00        84           0
# 2           Geraldton      AU -28.77  114.60     59.00        93          75
# 3        Marsá Maţrūḩ      EG  31.35   27.25     64.40        77          40
# 4             Ushuaia      AR -54.80  -68.30     46.40        93          75
# 5     Arraial do Cabo      BR -22.97  -42.03     70.77        80          33
# 6               Airai      TL  -8.93  125.41     79.30        37           0
# 7              Narsaq      GL  60.92  -46.05     24.80        85          65
# 8              Hobart      AU -42.88  147.33     68.00        67          75
# 9      Santa Catalina      PH   9.33  122.86     87.80        66          75
#
#    Wind Speed Current Description
# 0        3.36    scattered clouds
# 1        4.72           clear sky
# 2       14.99       moderate rain
# 3       10.58    scattered clouds
# 4        4.70       broken clouds
# 5       14.20    scattered clouds
# 6        2.77           clear sky
# 7        3.36   light shower snow
# 8        8.05         shower rain
# 9        9.17       broken clouds

# %%
# Export the city data into a .csv file. OPTION 1

weatherPy_Database.to_csv("WeatherPy_Database.csv", index=False, header=True)
